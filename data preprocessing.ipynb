# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_prp=pd.read_csv('/content/drive/My Drive/Data.csv')

# %%
data_prp
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data_prp[1:]
# Out:
#    Country   Age   Salary Purchased
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data_prp.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
data_prp.fillna(data_prp['Age'].mean(),inplace=True)

# %%
data_prp.fillna(data_prp['Salary'].mean(),inplace=True)

# %%
data_prp.isnull().sum()
# Out:
# Country      0
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
data_prp
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000     38.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
from sklearn.preprocessing import LabelEncoder


lc=LabelEncoder()
data_prp['Purchased']=lc.fit_transform(data_prp['Purchased'])

# %%
data_prp
# Out:
#    Country        Age        Salary  Purchased
# 0   France  44.000000  72000.000000          0
# 1    Spain  27.000000  48000.000000          1
# 2  Germany  30.000000  54000.000000          0
# 3    Spain  38.000000  61000.000000          0
# 4  Germany  40.000000     38.777778          1
# 5   France  35.000000  58000.000000          1
# 6    Spain  38.777778  52000.000000          0
# 7   France  48.000000  79000.000000          1
# 8  Germany  50.000000  83000.000000          0
# 9   France  37.000000  67000.000000          1

# %%
from sklearn.preprocessing import LabelEncoder
encoding_cols=['Country']
label_encoders={}
for column in encoding_cols:
  label_encoders[column]=LabelEncoder()
  data_prp[column]= label_encoders[column].fit_transform(data_prp[column])

# %%
data_prp
# Out:
#    Country        Age        Salary  Purchased
# 0        0  44.000000  72000.000000          0
# 1        2  27.000000  48000.000000          1
# 2        1  30.000000  54000.000000          0
# 3        2  38.000000  61000.000000          0
# 4        1  40.000000     38.777778          1
# 5        0  35.000000  58000.000000          1
# 6        2  38.777778  52000.000000          0
# 7        0  48.000000  79000.000000          1
# 8        1  50.000000  83000.000000          0
# 9        0  37.000000  67000.000000          1

# %%
data_prp['Purchased']=data_prp['Purchased'].replace({'No':0,'Yes':1})

# %%
data_prp
# Out:
#    Country        Age        Salary  Purchased
# 0        0  44.000000  72000.000000          0
# 1        2  27.000000  48000.000000          1
# 2        1  30.000000  54000.000000          0
# 3        2  38.000000  61000.000000          0
# 4        1  40.000000     38.777778          1
# 5        0  35.000000  58000.000000          1
# 6        2  38.777778  52000.000000          0
# 7        0  48.000000  79000.000000          1
# 8        1  50.000000  83000.000000          0
# 9        0  37.000000  67000.000000          1
