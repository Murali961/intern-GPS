# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-3b8a479202a4> in <cell line: 1>()
# ----> 1 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
df=pd.read_excel('/content/drive/My Drive/ML Data Science/Online_shopping.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-30f38a1fa13d> in <cell line: 1>()
# ----> 1 df=pd.read_excel('/content/drive/My Drive/ML Data Science/Online_shopping.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# --> 478         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479     elif engine and engine != io.engine:
#     480         raise ValueError(
#
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                                lower  \
# 0    536365    85123A   white hanging heart t-light holder
# 1    536365     71053                  white metal lantern
# 2    536365    84406B       cream cupid hearts coat hanger
# 3    536365    84029G  knitted union flag hot water bottle
# 4    536365    84029E       red woolly hottie white heart.
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1       3.39     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   lower        1816 non-null    object
#  3   Description  540455 non-null  object
#  4   Quantity     541909 non-null  int64
#  5   InvoiceDate  541909 non-null  datetime64[ns]
#  6   UnitPrice    541909 non-null  float64
#  7   CustomerID   406829 non-null  float64
#  8   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 37.2+ MB

# %%
df['Country'].head(100)
# Out:
# 0     United Kingdom
# 1     United Kingdom
# 2     United Kingdom
# 3     United Kingdom
# 4     United Kingdom
#            ...
# 95    United Kingdom
# 96    United Kingdom
# 97    United Kingdom
# 98    United Kingdom
# 99    United Kingdom
# Name: Country, Length: 100, dtype: object

# %%
df_hos=pd.read_csv('/content/drive/My Drive/Hospital+Patient+Records/patients.csv')
#df=pd.read_excel('/content/drive/My Drive/ML Data Science/Online_shopping.xlsx')

# %%
df_hos.tail(100)
# Out:
#                                        Id   BIRTHDATE DEATHDATE PREFIX  \
# 874  ac02d86d-bf74-382d-1718-2b24132d5ab1  1977-01-30       NaN    Mr.
# 875  899fe4f6-22a0-3a63-e58b-ee2d8d280df3  1952-06-28       NaN   Mrs.
# 876  b2b5f8d2-9ba8-f517-5ce5-3f246a0eee52  1922-04-15       NaN    Mr.
# 877  12e05e42-1c47-1284-9c84-b1c242839fc3  1950-04-14       NaN   Mrs.
# 878  b5989ff6-65d3-3ec8-8215-8c13f84e4251  1938-07-14       NaN   Mrs.
# ..                                    ...         ...       ...    ...
# 969  d684571e-a784-ef61-429e-06fa0d2b1637  1924-03-15       NaN    Mr.
# 970  13c6f26e-17b7-f534-04db-78a26b26018d  1940-10-31       NaN   Mrs.
# 971  521e998b-ff0e-767f-b0ee-2bdf1168d66c  1943-04-18       NaN    Mr.
# 972  b57e24a2-2e48-12f9-3293-c88745cfdc3f  1941-04-28       NaN   Mrs.
# 973  204f8028-72f8-d6f8-761f-79ebf9f02311  1923-02-14       NaN   Mrs.
#
#            FIRST          LAST SUFFIX       MAIDEN MARITAL   RACE  \
# ...

# %%
df_hos.describe()
# Out:
#                ZIP         LAT         LON
# count   832.000000  974.000000  974.000000
# mean   2152.421875   42.337359  -71.027524
# std      75.462146    0.047594    0.069375
# min    1801.000000   42.204921  -71.165648
# 25%    2121.000000   42.313366  -71.068002
# 50%    2135.000000   42.343794  -71.038397
# 75%    2163.000000   42.371594  -70.999202
# max    2472.000000   42.495464  -70.730824

# %%
df_hos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          974 non-null    object
#  1   BIRTHDATE   974 non-null    object
#  2   DEATHDATE   154 non-null    object
#  3   PREFIX      974 non-null    object
#  4   FIRST       974 non-null    object
#  5   LAST        974 non-null    object
#  6   SUFFIX      21 non-null     object
#  7   MAIDEN      386 non-null    object
#  8   MARITAL     973 non-null    object
#  9   RACE        974 non-null    object
#  10  ETHNICITY   974 non-null    object
#  11  GENDER      974 non-null    object
#  12  BIRTHPLACE  974 non-null    object
#  13  ADDRESS     974 non-null    object
#  14  CITY        974 non-null    object
#  15  STATE       974 non-null    object
#  16  COUNTY      974 non-null    object
#  17  ZIP         832 non-null    float64
#  18  LAT         974 non-null    float64
# ...

# %%
df_hos.isnull().sum()
# Out:
# Id              0
# BIRTHDATE       0
# DEATHDATE     820
# PREFIX          0
# FIRST           0
# LAST            0
# SUFFIX        953
# MAIDEN        588
# MARITAL         1
# RACE            0
# ETHNICITY       0
# GENDER          0
# BIRTHPLACE      0
# ADDRESS         0
# CITY            0
# STATE           0
# COUNTY          0
# ZIP           142
# LAT             0
# LON             0
# dtype: int64

# %%
df_hos['CITY'].value_counts(normalize=True)
# Out:
# CITY
# Boston            0.555441
# Quincy            0.082136
# Cambridge         0.046201
# Revere            0.043121
# Chelsea           0.040041
# Weymouth          0.037988
# Somerville        0.025667
# Hingham           0.022587
# Winthrop          0.022587
# Brookline         0.017454
# Everett           0.016427
# Hull              0.015400
# Medford           0.013347
# Cohasset          0.010267
# Braintree         0.010267
# Scituate          0.008214
# Malden            0.008214
# Newton            0.006160
# Stoneham          0.005133
# North Scituate    0.003080
# Reading           0.002053
# Winchester        0.001027
# Waltham           0.001027
# Belmont           0.001027
# Melrose           0.001027
# Norwell           0.001027
# Milton            0.001027
# Lynnfield         0.001027
# Watertown         0.001027
# Name: proportion, dtype: float64

# %%
df_hos['CITY'].describe()
# Out:
# count        974
# unique        29
# top       Boston
# freq         541
# Name: CITY, dtype: object

# %%
df_hos['CITY'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 974 entries, 0 to 973
# Series name: CITY
# Non-Null Count  Dtype
# --------------  -----
# 974 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
df_hos1=df_hos.copy()

# %%
df_hos1.head()
# Out:
#                                      Id   BIRTHDATE   DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19         NaN   Mrs.
# 1  6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940-02-19         NaN    Mr.
# 2  8123d076-0886-9007-e956-d5864aa121a7  1958-06-04         NaN    Mr.
# 3  770518e4-6133-648e-60c9-071eb2f0e2ce  1928-12-25  2017-09-29    Mr.
# 4  f96addf5-81b9-0aab-7855-d208d3d352c5  1928-12-25  2014-02-23    Mr.
#
#        FIRST           LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY  \
# 0  Nikita578      Erdman779    NaN  Leannon79       M  white  nonhispanic
# 1    Zane918  Hodkiewicz467    NaN        NaN       M  white  nonhispanic
# 2   Quinn173   Marquardt819    NaN        NaN       M  white  nonhispanic
# 3    Abel832     Smitham825    NaN        NaN       M  white     hispanic
# 4   Edwin773     Labadie908    NaN        NaN       M  white     hispanic
#
#   GENDER                    BIRTHPLACE                       ADDRESS    CITY  \
# ...

# %%
df_hos1.isnull().sum()
# Out:
# Id              0
# BIRTHDATE       0
# DEATHDATE     820
# PREFIX          0
# FIRST           0
# LAST            0
# SUFFIX        953
# MAIDEN        588
# MARITAL         1
# RACE            0
# ETHNICITY       0
# GENDER          0
# BIRTHPLACE      0
# ADDRESS         0
# CITY            0
# STATE           0
# COUNTY          0
# ZIP           142
# LAT             0
# LON             0
# dtype: int64

# %%
df_hos1.dropna(axis=0,how='any',inplace=True)

# %%
df_hos1.isnull().sum()
# Out:
# Id            0.0
# BIRTHDATE     0.0
# DEATHDATE     0.0
# PREFIX        0.0
# FIRST         0.0
# LAST          0.0
# SUFFIX        0.0
# MAIDEN        0.0
# MARITAL       0.0
# RACE          0.0
# ETHNICITY     0.0
# GENDER        0.0
# BIRTHPLACE    0.0
# ADDRESS       0.0
# CITY          0.0
# STATE         0.0
# COUNTY        0.0
# ZIP           0.0
# LAT           0.0
# LON           0.0
# dtype: float64

# %%
df_hos1.head()
# Out:
# Empty DataFrame
# Columns: [Id, BIRTHDATE, DEATHDATE, PREFIX, FIRST, LAST, SUFFIX, MAIDEN, MARITAL, RACE, ETHNICITY, GENDER, BIRTHPLACE, ADDRESS, CITY, STATE, COUNTY, ZIP, LAT, LON]
# Index: []

# %%
df_hos1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          0 non-null      object
#  1   BIRTHDATE   0 non-null      object
#  2   DEATHDATE   0 non-null      object
#  3   PREFIX      0 non-null      object
#  4   FIRST       0 non-null      object
#  5   LAST        0 non-null      object
#  6   SUFFIX      0 non-null      object
#  7   MAIDEN      0 non-null      object
#  8   MARITAL     0 non-null      object
#  9   RACE        0 non-null      object
#  10  ETHNICITY   0 non-null      object
#  11  GENDER      0 non-null      object
#  12  BIRTHPLACE  0 non-null      object
#  13  ADDRESS     0 non-null      object
#  14  CITY        0 non-null      object
#  15  STATE       0 non-null      object
#  16  COUNTY      0 non-null      object
#  17  ZIP         0 non-null      float64
#  18  LAT         0 non-null      float64
# ...

# %%
df_hos2=df_hos.copy()

# %%
df_hos2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          974 non-null    object
#  1   BIRTHDATE   974 non-null    object
#  2   DEATHDATE   154 non-null    object
#  3   PREFIX      974 non-null    object
#  4   FIRST       974 non-null    object
#  5   LAST        974 non-null    object
#  6   SUFFIX      21 non-null     object
#  7   MAIDEN      386 non-null    object
#  8   MARITAL     973 non-null    object
#  9   RACE        974 non-null    object
#  10  ETHNICITY   974 non-null    object
#  11  GENDER      974 non-null    object
#  12  BIRTHPLACE  974 non-null    object
#  13  ADDRESS     974 non-null    object
#  14  CITY        974 non-null    object
#  15  STATE       974 non-null    object
#  16  COUNTY      974 non-null    object
#  17  ZIP         832 non-null    float64
#  18  LAT         974 non-null    float64
# ...

# %%
df_hos2.isnull().sum()
# Out:
# Id              0
# BIRTHDATE       0
# DEATHDATE     820
# PREFIX          0
# FIRST           0
# LAST            0
# SUFFIX        953
# MAIDEN        588
# MARITAL         1
# RACE            0
# ETHNICITY       0
# GENDER          0
# BIRTHPLACE      0
# ADDRESS         0
# CITY            0
# STATE           0
# COUNTY          0
# ZIP           142
# LAT             0
# LON             0
# dtype: int64

# %%
df_hos2.dropna(axis=1,how='any',inplace=True)

# %%
df_hos2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          974 non-null    object
#  1   BIRTHDATE   974 non-null    object
#  2   PREFIX      974 non-null    object
#  3   FIRST       974 non-null    object
#  4   LAST        974 non-null    object
#  5   RACE        974 non-null    object
#  6   ETHNICITY   974 non-null    object
#  7   GENDER      974 non-null    object
#  8   BIRTHPLACE  974 non-null    object
#  9   ADDRESS     974 non-null    object
#  10  CITY        974 non-null    object
#  11  STATE       974 non-null    object
#  12  COUNTY      974 non-null    object
#  13  LAT         974 non-null    float64
#  14  LON         974 non-null    float64
# dtypes: float64(2), object(13)
# memory usage: 114.3+ KB

# %%
df_hos2.isnull().sum()
# Out:
# Id            0
# BIRTHDATE     0
# PREFIX        0
# FIRST         0
# LAST          0
# RACE          0
# ETHNICITY     0
# GENDER        0
# BIRTHPLACE    0
# ADDRESS       0
# CITY          0
# STATE         0
# COUNTY        0
# LAT           0
# LON           0
# dtype: int64

# %%
df_hos2.head(100)
# Out:
#                                       Id   BIRTHDATE PREFIX       FIRST  \
# 0   5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19   Mrs.   Nikita578
# 1   6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940-02-19    Mr.     Zane918
# 2   8123d076-0886-9007-e956-d5864aa121a7  1958-06-04    Mr.    Quinn173
# 3   770518e4-6133-648e-60c9-071eb2f0e2ce  1928-12-25    Mr.     Abel832
# 4   f96addf5-81b9-0aab-7855-d208d3d352c5  1928-12-25    Mr.    Edwin773
# ..                                   ...         ...    ...         ...
# 95  a920948a-7a64-e642-44b8-605ebcef09b1  1932-03-06    Mr.    Javier97
# 96  28fb4473-1424-1fda-aa52-105bd7abaec3  1954-10-04    Ms.  Delinda651
# 97  2147f600-50e5-d6c8-ae1e-930dc97e0664  1940-07-06    Mr.   Carter549
# 98  1685befc-4c9e-a69f-d65f-952abe34c74c  1974-04-21    Mr.    Luigi346
# 99  11844ff2-5918-bb2f-5b7d-65aa702f0cd8  1968-10-08   Mrs.   Izetta651
#
#               LAST      RACE    ETHNICITY GENDER  \
# 0        Erdman779     white  nonhispanic      F
# ...

# %%
df_hosts=df_hos2.drop(['STATE'],axis=1)

# %%
df_hosts.head()
# Out:
#                                      Id   BIRTHDATE PREFIX      FIRST  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19   Mrs.  Nikita578
# 1  6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940-02-19    Mr.    Zane918
# 2  8123d076-0886-9007-e956-d5864aa121a7  1958-06-04    Mr.   Quinn173
# 3  770518e4-6133-648e-60c9-071eb2f0e2ce  1928-12-25    Mr.    Abel832
# 4  f96addf5-81b9-0aab-7855-d208d3d352c5  1928-12-25    Mr.   Edwin773
#
#             LAST   RACE    ETHNICITY GENDER                    BIRTHPLACE  \
# 0      Erdman779  white  nonhispanic      F  Wakefield  Massachusetts  US
# 1  Hodkiewicz467  white  nonhispanic      M  Brookline  Massachusetts  US
# 2   Marquardt819  white  nonhispanic      M    Gardner  Massachusetts  US
# 3     Smitham825  white     hispanic      M   Randolph  Massachusetts  US
# 4     Labadie908  white     hispanic      M       Stow  Massachusetts  US
#
#                         ADDRESS    CITY          COUNTY        LAT        LON
# ...
